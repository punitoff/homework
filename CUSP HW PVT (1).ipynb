# %%
fname = '311_service_requests_2020.csv'
url = 'https://data.boston.gov/dataset/8048697b-ad64-4bfc-b090-ee00169f2323/resource/6ff6a6fd-3141-4440-a880-6f60a37fe789/download/tmpxbo51van.csv'
# alternative url
url = 'https://raw.githubusercontent.com/CUSP2021PUI/Data/main/311_service_requests_2020.csv'

# %%
import pandas as pd
df=pd.DataFrame()
boston311 = pd.read_csv(url)

# %%
boston311
# Out:
#         case_enquiry_id              open_dt            target_dt closed_dt  \
# 0          101003156172  2020-01-10 11:32:00  2020-05-09 11:32:13       NaN
# 1          101003171366  2020-01-16 12:08:00  2021-01-15 12:09:19       NaN
# 2          101003175987  2020-01-22 15:34:00  2020-01-23 15:34:03       NaN
# 3          101003180345  2020-01-27 21:33:00  2020-02-11 08:30:00       NaN
# 4          101003183226  2020-01-30 14:55:58  2020-04-29 14:55:59       NaN
# ...                 ...                  ...                  ...       ...
# 161712     101003425595  2020-08-30 21:49:00  2020-09-01 08:30:00       NaN
# 161713     101003425606  2020-08-30 22:20:26  2020-09-02 08:30:00       NaN
# 161714     101003425616  2020-08-30 23:05:02                  NaN       NaN
# 161715     101003425620  2020-08-30 23:28:00                  NaN       NaN
# 161716     101003425628  2020-08-30 23:47:00                  NaN       NaN
#
#          ontime case_status closure_reason  \
# ...

# %%
boston311.head(4)
# Out:
#    case_enquiry_id              open_dt            target_dt closed_dt  \
# 0     101003156172  2020-01-10 11:32:00  2020-05-09 11:32:13       NaN
# 1     101003171366  2020-01-16 12:08:00  2021-01-15 12:09:19       NaN
# 2     101003175987  2020-01-22 15:34:00  2020-01-23 15:34:03       NaN
# 3     101003180345  2020-01-27 21:33:00  2020-02-11 08:30:00       NaN
#
#     ontime case_status closure_reason                        case_title  \
# 0  OVERDUE        Open                 Unsatisfactory Living Conditions
# 1   ONTIME        Open                                New Tree Requests
# 2  OVERDUE        Open                      Sidewalk Repair (Make Safe)
# 3  OVERDUE        Open                                       PRINTED :
#
#                          subject               reason  ... police_district  \
# 0          Inspectional Services              Housing  ...              B3
# 1  Parks & Recreation Department                Trees  ...             E18
# ...

# %%
len(boston311)
# Out:
# 161717

# %%
boston311.subject.unique()
# Out:
# array(['Inspectional Services', 'Parks & Recreation Department',
#        'Public Works Department', 'Property Management',
#        "Mayor's 24 Hour Hotline", 'Transportation - Traffic Division',
#        'Animal Control', 'Boston Water & Sewer Commission',
#        'Boston Police Department', 'Consumer Affairs & Licensing',
#        'Neighborhood Services'], dtype=object)

# %%
boston311.neighborhood.unique()
# Out:
# array(['Dorchester', 'Hyde Park', 'Boston', 'Charlestown', 'East Boston',
#        'Back Bay', 'Mission Hill', 'Jamaica Plain', 'Beacon Hill',
#        'South Boston / South Boston Waterfront', 'Roxbury',
#        'Allston / Brighton', 'South End', 'Roslindale', 'West Roxbury',
#        ' ', 'Fenway / Kenmore / Audubon Circle / Longwood',
#        'Downtown / Financial District', 'South Boston',
#        'Greater Mattapan', 'Allston', nan, 'Brighton', 'Mattapan',
#        'Chestnut Hill'], dtype=object)

# %%
len(boston311.neighborhood.unique())
# Out:
# 25

# %%
boston311['subject'].value_counts()
# Out:
# Public Works Department              85739
# Transportation - Traffic Division    33328
# Inspectional Services                14022
# Mayor's 24 Hour Hotline              12207
# Parks & Recreation Department        10935
# Animal Control                        2196
# Property Management                   2170
# Boston Water & Sewer Commission        748
# Boston Police Department               344
# Consumer Affairs & Licensing            18
# Neighborhood Services                   10
# Name: subject, dtype: int64

# %%
boston311['subject']
# Out:
# 0                 Inspectional Services
# 1         Parks & Recreation Department
# 2               Public Works Department
# 3               Public Works Department
# 4                 Inspectional Services
#                       ...
# 161712          Public Works Department
# 161713          Public Works Department
# 161714          Public Works Department
# 161715         Boston Police Department
# 161716         Boston Police Department
# Name: subject, Length: 161717, dtype: object

# %%
boston311['subject'].value_counts()
# Out:
# Public Works Department              85739
# Transportation - Traffic Division    33328
# Inspectional Services                14022
# Mayor's 24 Hour Hotline              12207
# Parks & Recreation Department        10935
# Animal Control                        2196
# Property Management                   2170
# Boston Water & Sewer Commission        748
# Boston Police Department               344
# Consumer Affairs & Licensing            18
# Neighborhood Services                   10
# Name: subject, dtype: int64

# %%
boston311[['neighborhood','case_enquiry_id']].groupby(by=['neighborhood']).count().plot.bar()
# Out:
# <AxesSubplot:xlabel='neighborhood'>

# %%
year=2015; boro='brooklyn'

# %%
fname=str(year)+'_'+boro+'.xls'

# %%
url = 'https://github.com/CUSP2021PUI/Data/blob/main/RollingSale/'+fname+'?raw=true'

# %%
re_sales = pd.read_excel(url,skiprows=4)
re_sales.head()
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          3  BATH BEACH
# 1          3  BATH BEACH
# 2          3  BATH BEACH
# 3          3  BATH BEACH
# 4          3  BATH BEACH
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0  01  ONE FAMILY DWELLINGS                                          1
# 1  01  ONE FAMILY DWELLINGS                                          1
# 2  01  ONE FAMILY DWELLINGS                                          1
# 3  01  ONE FAMILY DWELLINGS                                          1
# 4  01  ONE FAMILY DWELLINGS                                          1
#
#    BLOCK\n  LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0     6360     22                                      A5
# 1     6361     17                                      A5
# 2     6371     60                                      A9
# 3     6372     48                                      S1
# 4     6373     73                                      A1
#
# ...

# %%
re_sales.head()
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          3  BATH BEACH
# 1          3  BATH BEACH
# 2          3  BATH BEACH
# 3          3  BATH BEACH
# 4          3  BATH BEACH
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0  01  ONE FAMILY DWELLINGS                                          1
# 1  01  ONE FAMILY DWELLINGS                                          1
# 2  01  ONE FAMILY DWELLINGS                                          1
# 3  01  ONE FAMILY DWELLINGS                                          1
# 4  01  ONE FAMILY DWELLINGS                                          1
#
#    BLOCK\n  LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0     6360     22                                      A5
# 1     6361     17                                      A5
# 2     6371     60                                      A9
# 3     6372     48                                      S1
# 4     6373     73                                      A1
#
# ...

# %%
re_sales.columns
# Out:
# Index(['BOROUGH\n', 'NEIGHBORHOOD\n', 'BUILDING CLASS CATEGORY\n',
#        'TAX CLASS AT PRESENT\n', 'BLOCK\n', 'LOT\n', 'EASE-MENT\n',
#        'BUILDING CLASS AT PRESENT\n', 'ADDRESS\n', 'APARTMENT NUMBER\n',
#        'ZIP CODE\n', 'RESIDENTIAL UNITS\n', 'COMMERCIAL UNITS\n',
#        'TOTAL UNITS\n', 'LAND SQUARE FEET\n', 'GROSS SQUARE FEET\n',
#        'YEAR BUILT\n', 'TAX CLASS AT TIME OF SALE\n',
#        'BUILDING CLASS AT TIME OF SALE\n', 'SALE PRICE\n', 'SALE DATE\n'],
#       dtype='object')

# %%
re_sales['LAND SQUARE FEET\n'].sum()
# Out:
# 56770287

# %%
re_sales['SALE PRICE\n'].sum()
# Out:
# 19990077327

# %%
a=re_sales[['ZIP CODE\n','SALE PRICE\n']].groupby(by=['ZIP CODE\n']).mean()
a
# Out:
#             SALE PRICE\n
# ZIP CODE\n
# 0           4.892857e+05
# 11201       1.618065e+06
# 11203       4.190376e+05
# 11204       4.908219e+05
# 11205       7.062129e+05
# 11206       1.213060e+06
# 11207       4.006299e+05
# 11208       3.979557e+05
# 11209       5.333751e+05
# 11210       6.411172e+05
# 11211       1.272336e+06
# 11212       7.217267e+05
# 11213       7.467856e+05
# 11214       5.148053e+05
# 11215       1.200128e+06
# 11216       7.310867e+05
# 11217       1.619211e+06
# 11218       7.183455e+05
# 11219       4.863094e+05
# 11220       6.457887e+05
# 11221       5.739595e+05
# 11222       1.250622e+06
# 11223       6.056926e+05
# 11224       8.177449e+05
# 11225       1.114451e+06
# 11226       1.403538e+06
# 11227       6.000000e+05
# 11228       5.305021e+05
# 11229       4.220108e+05
# 11230       5.853335e+05
# 11231       1.539066e+06
# 11232       1.392873e+06
# 11233       5.631594e+05
# 11234       3.765121e+05
# 11235       4.385999e+05
# ...

# %%
c=a.sort_values(by=['SALE PRICE\n'], ascending=False)

# %%
# Out:
# SALE PRICE\n    296000.0
# Name: 11239, dtype: float64

# %%
re_sales[['ZIP CODE\n','SALE PRICE\n']].groupby(by=['ZIP CODE\n']).mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='ZIP CODE\n'>

# %%
re_sales.describe()
# Out:
#        BOROUGH\n       BLOCK\n         LOT\n    ZIP CODE\n  \
# count    25362.0  25362.000000  25362.000000  25362.000000
# mean         3.0   4207.714534    281.084418  11217.017270
# std          0.0   2649.487442    492.384071    186.770716
# min          3.0     20.000000      1.000000      0.000000
# 25%          3.0   1768.000000     21.000000  11209.000000
# 50%          3.0   4149.000000     46.000000  11219.000000
# 75%          3.0   6540.000000    103.000000  11231.000000
# max          3.0   8955.000000   9033.000000  11249.000000
#
#        RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n  TOTAL UNITS\n  \
# count         25362.000000        25362.000000   25362.000000
# mean              2.376981            0.185474       2.603817
# std               7.803233            2.711002       8.286863
# min               0.000000            0.000000       0.000000
# 25%               1.000000            0.000000       1.000000
# ...

# %%
re_sales['SALE PRICE\n'].mean()
# Out:
# 788190.100425834

# %%
import geopandas as gpd
url ='https://raw.githubusercontent.com/CUSP2021PUI/Data/main/Street%20Pavement%20Rating.geojson'
rating = gpd.read_file(url)

# %%
rating.shape
# Out:
# (81209, 13)

# %%
rating.head()
# Out:
#   hagstrom bus segment_id     shape_leng truck rating_b usage_class  \
# 0        0   0         56  249.903981561     0        0        None
# 1        0   0         58  260.837113924     0        0        None
# 2        0   0         73  250.888421415     0        6        None
# 3        0   0        106  231.814581077     0        9        None
# 4        0   0        123  276.441675585     0        8        None
#
#   rating_fy_s length width rating_word               rating_date  \
# 0           0    414    30          NR                       NaT
# 1           0    425    30          NR                       NaT
# 2        2019    202    30        FAIR 2019-03-12 00:00:00+00:00
# 3        2019    232    30        GOOD 2019-03-12 00:00:00+00:00
# 4        2013    212    30        GOOD 2013-06-19 00:00:00+00:00
#
#                                             geometry
# 0  MULTILINESTRING ((-74.24916 40.49872, -74.2500...
# 1  MULTILINESTRING ((-74.24935 40.49944, -74.2502...
# ...

# %%
rating.iloc[:,:-1].describe()
# Out:
# /var/folders/6p/_89gpvq92dndfj0fcdlyzz940000gn/T/ipykernel_24462/966950840.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   rating.iloc[:,:-1].describe()
#        hagstrom    bus segment_id     shape_leng  truck rating_b usage_class  \
# count     81209  81209      81209          81209  81209    81209       57698
# unique        2      2      81209          41590      2       11           3
# top           0      0         56  260.499520153      0        8           L
# freq      71660  68374          1            359  73352    25137       40816
# first       NaN    NaN        NaN            NaN    NaN      NaN         NaN
# last        NaN    NaN        NaN            NaN    NaN      NaN         NaN
#
#        rating_fy_s length  width rating_word                rating_date
# ...

# %%
rating['length'] = rating['length'].astype(int)
rating['length'].describe()
# Out:
# count    81209.000000
# mean       382.526321
# std        250.159451
# min          6.000000
# 25%        238.000000
# 50%        288.000000
# 75%        505.000000
# max       6795.000000
# Name: length, dtype: float64

# %%
rating['rating_word'].value_counts()
# Out:
# GOOD    47178
# FAIR    24732
# NR       8220
# POOR     1079
# Name: rating_word, dtype: int64

# %%
rating[['rating_word','length']].groupby(by=['rating_word']).sum()
# Out:
#                length
# rating_word
# FAIR          9291301
# GOOD         18521671
# NR            2824328
# POOR           427280

# %%
Poor_rating = rating.loc[(rating["rating_word"] == "POOR")]

# %%
Poor_rating
# Out:
#       hagstrom bus segment_id     shape_leng truck rating_b usage_class  \
# 64           0   0       4702  447.393562761     0        3           L
# 140          0   0       1043  279.892836636     0        3        None
# 167          0   0       3021  644.643312228     0        3           L
# 179          0   0       3239  405.571202133     0        3           L
# 402          0   0       4202  507.063112443     0        2           L
# ...        ...  ..        ...            ...   ...      ...         ...
# 80903        0   0     100532  258.642610565     0        3           L
# 81018        0   0      92491  175.934646957     0        3           L
# 81023        0   0      92609  607.003294884     0        3           L
# 81024        0   0      92625  468.001068375     0        3           L
# 81136        0   0      92730  647.093501745     0        3           L
#
#       rating_fy_s  length  width rating_word               rating_date  \
# ...

# %%
rating[['rating_word','length']].groupby(by=['rating_word']).sum().plot.pie(y='length')
# Out:
# <AxesSubplot: ylabel='length'>

# %%
rating.plot(column=None, figsize=(10,10))
# Out:
# <AxesSubplot: >

# %%
Poor_rating.plot(column='rating_word',cmap='Spectral',figsize=(10,10),legend=True)
# Out:
# <AxesSubplot: >

# %%
rating.plot(column='rating_word == POOR',cmap='Spectral',figsize=(10,10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rating_word == POOR'
#
# ...

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/nychealth/coronavirus-data/7953c97d1e58bbed9934ea04affb12ca74d9c0fb/data-by-modzcta.csv'
# alternative url
url = 'https://raw.githubusercontent.com/CUSP2021PUI/Data/main/COVID19.csv'
df = pd.read_csv(url)

# %%
df
# Out:
#      MODIFIED_ZCTA                        NEIGHBORHOOD_NAME BOROUGH_GROUP  \
# 0            10001               Chelsea/NoMad/West Chelsea     Manhattan
# 1            10002                Chinatown/Lower East Side     Manhattan
# 2            10003  East Village/Gramercy/Greenwich Village     Manhattan
# 3            10004                       Financial District     Manhattan
# 4            10005                       Financial District     Manhattan
# ..             ...                                      ...           ...
# 172          11691                    Edgemere/Far Rockaway        Queens
# 173          11692                         Arverne/Edgemere        Queens
# 174          11693                    Arverne/Broad Channel        Queens
# 175          11694      Belle Harbor-Neponsit/Rockaway Park        Queens
# 176          11697                             Breezy Point        Queens
#
#      COVID_CASE_COUNT  COVID_CASE_RATE  POP_DENOMINATOR  COVID_DEATH_COUNT  \
# ...

# %%
df.BOROUGH_GROUP
# Out:
# 0      Manhattan
# 1      Manhattan
# 2      Manhattan
# 3      Manhattan
# 4      Manhattan
#          ...
# 172       Queens
# 173       Queens
# 174       Queens
# 175       Queens
# 176       Queens
# Name: BOROUGH_GROUP, Length: 177, dtype: object

# %%
df['BOROUGH_GROUP']
# Out:
# 0      Manhattan
# 1      Manhattan
# 2      Manhattan
# 3      Manhattan
# 4      Manhattan
#          ...
# 172       Queens
# 173       Queens
# 174       Queens
# 175       Queens
# 176       Queens
# Name: BOROUGH_GROUP, Length: 177, dtype: object

# %%
df['BOROUGH_GROUP'].value_counts()
# Out:
# Queens           59
# Manhattan        44
# Brooklyn         37
# Bronx            25
# Staten Island    12
# Name: BOROUGH_GROUP, dtype: int64

# %%
new_df = df[['BOROUGH_GROUP','COVID_CASE_COUNT']].copy()

# %%
new_df
# Out:
#     BOROUGH_GROUP  COVID_CASE_COUNT
# 0       Manhattan               441
# 1       Manhattan              1335
# 2       Manhattan               542
# 3       Manhattan                40
# 4       Manhattan                95
# ..            ...               ...
# 172        Queens              2690
# 173        Queens               698
# 174        Queens               350
# 175        Queens               787
# 176        Queens               115
#
# [177 rows x 2 columns]

# %%
new_df[['BOROUGH_GROUP', 'COVID_CASE_COUNT']].groupby(by=['BOROUGH_GROUP']).sum()
# Out:
#                COVID_CASE_COUNT
# BOROUGH_GROUP
# Bronx                     50849
# Brooklyn                  61344
# Manhattan                 28628
# Queens                    68148
# Staten Island             14886

# %%
new_df[['BOROUGH_GROUP', 'COVID_CASE_COUNT']].groupby(by=['BOROUGH_GROUP']).sum().plot.bar()
# Out:
# <AxesSubplot: xlabel='BOROUGH_GROUP'>

# %%
new1_df = df[['BOROUGH_GROUP','PERCENT_POSITIVE']].copy()

# %%
new1_df
# Out:
#     BOROUGH_GROUP  PERCENT_POSITIVE
# 0       Manhattan              6.58
# 1       Manhattan              7.73
# 2       Manhattan              3.56
# 3       Manhattan              4.90
# 4       Manhattan              4.55
# ..            ...               ...
# 172        Queens             15.30
# 173        Queens             13.87
# 174        Queens             14.11
# 175        Queens             15.40
# 176        Queens              7.47
#
# [177 rows x 2 columns]

# %%
new2_df = df[['BOROUGH_GROUP','COVID_CASE_COUNT', 'PERCENT_POSITIVE', 'TOTAL_COVID_TESTS' ]].copy()

# %%
new2_df
# Out:
#     BOROUGH_GROUP  COVID_CASE_COUNT  PERCENT_POSITIVE  TOTAL_COVID_TESTS
# 0       Manhattan               441              6.58               6704
# 1       Manhattan              1335              7.73              17276
# 2       Manhattan               542              3.56              15204
# 3       Manhattan                40              4.90                817
# 4       Manhattan                95              4.55               2090
# ..            ...               ...               ...                ...
# 172        Queens              2690             15.30              17584
# 173        Queens               698             13.87               5031
# 174        Queens               350             14.11               2480
# 175        Queens               787             15.40               5109
# 176        Queens               115              7.47               1540
#
# [177 rows x 4 columns]

# %%
x=new2_df[['BOROUGH_GROUP', 'COVID_CASE_COUNT', 'PERCENT_POSITIVE', 'TOTAL_COVID_TESTS']].groupby(by=['BOROUGH_GROUP']).sum()

# %%
x
# Out:
#                COVID_CASE_COUNT  PERCENT_POSITIVE  TOTAL_COVID_TESTS
# BOROUGH_GROUP
# Bronx                     50849            357.09             352106
# Brooklyn                  61344            396.72             567476
# Manhattan                 28628            287.61             424706
# Queens                    68148            762.19             514959
# Staten Island             14886            165.27             109487

# %%
x=new2_df[['BOROUGH_GROUP', 'COVID_CASE_COUNT', 'PERCENT_POSITIVE', 'TOTAL_COVID_TESTS']].groupby(by=['BOROUGH_GROUP']).sum()

# %%
x['PCP'] = x.apply(lambda row: 100*row.COVID_CASE_COUNT / row.TOTAL_COVID_TESTS, axis=1)

# %%
x
# Out:
#                COVID_CASE_COUNT  PERCENT_POSITIVE  TOTAL_COVID_TESTS  \
# BOROUGH_GROUP
# Bronx                     50849            357.09             352106
# Brooklyn                  61344            396.72             567476
# Manhattan                 28628            287.61             424706
# Queens                    68148            762.19             514959
# Staten Island             14886            165.27             109487
#
#                      PCP
# BOROUGH_GROUP
# Bronx          14.441390
# Brooklyn       10.809973
# Manhattan       6.740663
# Queens         13.233675
# Staten Island  13.596135

# %%
new3_df = df[['BOROUGH_GROUP','PERCENT_POSITIVE', 'POP_DENOMINATOR', 'COVID_CASE_COUNT']].copy()

# %%
new3_df
# Out:
#     BOROUGH_GROUP  PERCENT_POSITIVE  POP_DENOMINATOR  COVID_CASE_COUNT  \
# 0       Manhattan              6.58         23563.03               441
# 1       Manhattan              7.73         76755.41              1335
# 2       Manhattan              3.56         53801.62               542
# 3       Manhattan              4.90          3650.61                40
# 4       Manhattan              4.55          8396.11                95
# ..            ...               ...              ...               ...
# 172        Queens             15.30         64759.02              2690
# 173        Queens             13.87         20120.24               698
# 174        Queens             14.11         12381.27               350
# 175        Queens             15.40         20355.78               787
# 176        Queens              7.47          3536.69               115
#
#           PCP      PCPD
# 0    1.871576  1.871576
# 1    1.739291  1.739291
# 2    1.007405  1.007405
# ...

# %%
new3_df
# Out:
#     BOROUGH_GROUP  PERCENT_POSITIVE  POP_DENOMINATOR  COVID_CASE_COUNT  \
# 0       Manhattan              6.58         23563.03               441
# 1       Manhattan              7.73         76755.41              1335
# 2       Manhattan              3.56         53801.62               542
# 3       Manhattan              4.90          3650.61                40
# 4       Manhattan              4.55          8396.11                95
# ..            ...               ...              ...               ...
# 172        Queens             15.30         64759.02              2690
# 173        Queens             13.87         20120.24               698
# 174        Queens             14.11         12381.27               350
# 175        Queens             15.40         20355.78               787
# 176        Queens              7.47          3536.69               115
#
#           PCP      PCPD
# 0    1.871576  1.871576
# 1    1.739291  1.739291
# 2    1.007405  1.007405
# ...

# %%
z=new3_df[['BOROUGH_GROUP', 'COVID_CASE_COUNT', 'PERCENT_POSITIVE', 'POP_DENOMINATOR']].groupby(by=['BOROUGH_GROUP']).sum()

# %%
z
# Out:
#                COVID_CASE_COUNT  PERCENT_POSITIVE  POP_DENOMINATOR
# BOROUGH_GROUP
# Bronx                     50849            357.09       1434692.65
# Brooklyn                  61344            396.72       2582829.99
# Manhattan                 28628            287.61       1611943.49
# Queens                    68148            762.19       2288709.82
# Staten Island             14886            165.27        476179.01

# %%
z['PCPD'] = z.apply(lambda row: 100*row.COVID_CASE_COUNT / row.POP_DENOMINATOR, axis=1)

# %%
z
# Out:
#                COVID_CASE_COUNT  PERCENT_POSITIVE  POP_DENOMINATOR      PCPD
# BOROUGH_GROUP
# Bronx                     50849            357.09       1434692.65  3.544243
# Brooklyn                  61344            396.72       2582829.99  2.375069
# Manhattan                 28628            287.61       1611943.49  1.775993
# Queens                    68148            762.19       2288709.82  2.977573
# Staten Island             14886            165.27        476179.01  3.126135

# %%
del z["PERCENT_POSITIVE"]

# %%
z[['BOROUGH_GROUP', 'PCPD']].groupby(by=['BOROUGH_GROUP'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [113], line 1
# ----> 1 z[['BOROUGH_GROUP', 'PCPD']].groupby(by=['BOROUGH_GROUP'])
#
# File ~/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:6108, in Index._get_indexer_strict(self, key, axis_name)
#    6105 else:
#    6106     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6108 self._raise_if_missing(keyarr, indexer, axis_name)
#    6110 keyarr = self.take(indexer)
# ...
